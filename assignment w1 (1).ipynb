# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.READ DATA

# %%
iris=pd.read_excel('iris.xls')
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2.display columns

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3.calculate mean of each column

# %%
iris.mean(axis=0)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. to check null values in iris

# %%
iris.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# # 5.visualisation

# %% [markdown]
# # histogram , distribution of sepal width

# %%
plt.figure(figsize=(8,8))
plt.hist(iris['SW'],color='blue',rwidth=0.9)
plt.title('Distribution of SW',fontsize=16)
plt.xlabel('Sepal width',fontsize=16)
plt.ylabel('Frequency',fontsize=16)
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # histogram , distribution of sepal length

# %%
plt.figure(figsize=(8,8))
plt.hist(iris['SL'],color='violet',rwidth=0.9)
plt.title('Distribution of SL',fontsize=16)
plt.xlabel('Sepal Length',fontsize=14)
plt.ylabel('Frequency',fontsize=14)
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # distribution of petal length

# %%
plt.figure(figsize=(8,8))
plt.hist(iris['PL'],color='red',rwidth=0.9)
plt.title('Distribution of PL',fontsize=16)
plt.xlabel('Petal Length',fontsize=14)
plt.ylabel('Frequency',fontsize=14)
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # distribution of petal width

# %%
plt.figure(figsize=(8,8))
plt.hist(iris['PW'],color='green',rwidth=0.9)
plt.title('Distribution of PW',fontsize=16)
plt.xlabel('Petal Width',fontsize=14)
plt.ylabel('Frequency',fontsize=14)
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # scatter plot of sepal width vs sepal length

# %%
plt.figure(figsize=(8,6))
plt.subplot(2,1,1)
plt.scatter(iris['SL'],iris['SW'],s=10,marker='*',c='blue')
plt.title('Scatter plot of Sepal Lenth Vs Sepal Width',fontsize=16)
plt.xlabel('Sepal Length',fontsize=14)
plt.ylabel('Sepal Width',fontsize=14)


plt.subplot(2,1,2)
plt.scatter(iris['PL'],iris['PW'],s=10,marker='^',c='green')
plt.title('Scatter plot of Petal Length Vs Petal Width',fontsize=16)
plt.xlabel('Petal Length',fontsize=14)
plt.ylabel('Petal Width',fontsize=14)
plt.tight_layout()

# %% [markdown]
# # pairplot of iris data

# %%
sns.pairplot(iris)

# %% [markdown]
# # violin plot

# %%
sns.violinplot(y='SW',x='Classification',data=iris)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SW'>

# %% [markdown]
# # box plot

# %%
sns.boxplot(x='Classification',y='SL',data=iris)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SL'>

# %%
sns.boxplot(x='Classification',y='SW',data=iris)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SW'>

# %%
sns.boxplot(x='Classification',y='PL',data=iris)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PL'>

# %%
sns.boxplot(x='Classification',y='PW',data=iris)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PW'>
